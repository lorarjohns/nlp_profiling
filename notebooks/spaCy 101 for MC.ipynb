# %%
from Cython.Build import Inline
import pytest

# %% [markdown]
# The first thing to do when working with spaCy is import a language model and instantiate an nlp object with it.\*
#
# The nlp object creates a **pipeline** of NLP processing tasks. You can add pre-defined pipes to
#
# - **tokenize** raw text, i.e. segment it into tokens (roughly word-level)
# - **tag** your text with **part-of-speech** labels
# - **parse** your raw text to assign **dependency** labels
# - tag **named entities**
#
# ... and a lot of other fancy things. You can also define any kind of **custom pipe** that you want and create attributes that will be stored in the Token's metadata structure.
#
# Basically, this means your NLP pipeline all gets consolidated into one `nlp.pipe(docs, batch=batchsize)` call. Nice.
#
# \**(Later, you will want to use different models -- Either spaCy's pretrained vectors in the web corpora, or glove, or your own, but not right now.)

# %%
import spacy
from spacy.lang.en import English # languages are coded as classes
from spacy import displacy

# %% [markdown]
# The thing you are loading with `spacy.load()` is (usually) a [pre-trained statistical model](https://github.com/explosion/spacy-models)

# %%
nlp = spacy.load('en_core_web_sm') # create a pipeline with English rules

# %%
nlp.__dir__()
# Out:
# ['_meta',
#  '_path',
#  'vocab',
#  'tokenizer',
#  'pipeline',
#  'max_length',
#  '_optimizer',
#  '__module__',
#  'lang',
#  'Defaults',
#  '__doc__',
#  'factories',
#  '__init__',
#  'path',
#  'meta',
#  'tensorizer',
#  'tagger',
#  'parser',
#  'entity',
#  'linker',
#  'matcher',
#  'pipe_names',
#  'get_pipe',
#  'create_pipe',
#  'add_pipe',
#  'has_pipe',
#  'replace_pipe',
#  'rename_pipe',
#  'remove_pipe',
#  '__call__',
#  'disable_pipes',
#  'make_doc',
#  'update',
#  'rehearse',
#  'preprocess_gold',
#  'begin_training',
#  'resume_training',
#  'evaluate',
#  'use_params',
#  'pipe',
#  'to_disk',
#  'from_disk',
#  'to_bytes',
#  'from_bytes',
#  '__dict__',
#  '__weakref__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__getattribute__',
#  '__setattr__',
#  '__delattr__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__new__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
# see what's in the pipeline
print(nlp.pipeline)
for name in nlp.pipe_names:
    print(name)
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger object at 0x7fd9ac779390>), ('parser', <spacy.pipeline.pipes.DependencyParser object at 0x7fd9aa5fe708>), ('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x7fd9aa5fe768>)]
# tagger
# parser
# ner

# %%
doc = nlp("WASHINGTON — During a night of heavy drinking at an upscale London bar in May 2016, George Papadopoulos, a young foreign policy adviser to the Trump campaign, made a startling revelation to Australia’s top diplomat in Britain: Russia had political dirt on Hillary Clinton. About three weeks earlier, Mr. Papadopoulos had been told that Moscow had thousands of emails that would embarrass Mrs. Clinton, apparently stolen in an effort to try to damage her campaign. Exactly how much Mr. Papadopoulos said that night at the Kensington Wine Rooms with the Australian, Alexander Downer, is unclear. But two months later, when leaked Democratic emails began appearing online, Australian officials passed the information about Mr. Papadopoul
two met repeatedly in Manhattan. Mr. Millian has bragged of his ties to Mr. Trump — boasts that the president’s advisers have said are overstated. He headed an obscure organization called the Russian-American Chamber of Commerce, some of whose board members and clients are difficult to confirm. Congress is investigating where he fits into the swirl of contacts with the Trump campaign, although he has said he is unfairly being scrutinized only because of his support for Mr. Trump. Mr. Millian proposed that he and Mr. Papadopoulos form an energy-related business that would be financed by Russian billionaires “who are not under sanctions” and would “open all doors for us” at “any level all the way to the top.” One billionaire, he said, wanted to explore the idea of opening a Trump-branded hotel in Moscow. “I know the president will distance himself from business, but his children might be interested,” he wrote. Nothing came of his proposals, partly because Mr. Papadopoulos was hoping that Michael T. Flynn, then Mr. Trump’s pick to be national security adviser, might give him the energy portfolio at the National Security Council. The pair exchanged New Year’s greetings in the final hours of 2016. “Happy New Year, sir,” Mr. Papadopoulos wrote. “Thank you and same to you, George. Happy New Year!” Mr. Flynn responded, ahead of a year that seemed to hold great promise. But 2017 did not unfold that way. Within months, Mr. Flynn was fired, and both men were charged with lying to the F.B.I. And both became important witnesses in the investigation Mr. Papadopoulos had played a critical role in starting.")

# %% [markdown]
# The `Doc` object holds an array of `TokenC` structs.
#
# `__init__` constructs a doc from:
#
# >
# >vocab (Vocab): A vocabulary object, which must match any models you
# >    want to use (e.g. tokenizer, parser, entity recognizer).
# >words (list or None): A list of unicode strings to add to the document
# >    as words. If `None`, defaults to empty list.
# >spaces (list or None): A list of boolean values, of the same length as
# >    words. True means that the word is followed by a space, False means
# >    it is not. If `None`, defaults to `[True]*len(words)`
# >user_data (dict or None): Optional extra data to attach to the Doc.
#
#
#
# [source](https://github.com/explosion/spaCy/blob/master/spacy/tokens/doc.pyx)

# %%
print(doc.is_tagged, doc.is_parsed, doc.tensor, doc.noun_chunks_iterator)
# Out:
# True True [[ 8.756554   -3.1600325  -0.1917338  ...  1.118364   -3.0791821
#    2.7180376 ]
#  [ 0.9409258   2.2175236  -1.3412498  ... -0.2895214  -3.3159554
#    5.182918  ]
#  [-3.9862745  -2.5407963  -2.5230224  ...  6.717414   -1.7213043
#    3.3787484 ]
#  ...
#  [-1.9005902  -4.581986   -2.745854   ...  0.35454035 -1.842454
#    0.97634935]
#  [ 0.82343036 -2.4026475   2.5932384  ...  1.3355422  -1.4711387
#    3.4241068 ]
#  [ 0.5511681  -1.715608    3.2748218  ... -2.561218    0.4252711
#    1.0786207 ]] <function noun_chunks at 0x7fd9af5c76a8>

# %% [markdown]
# Tokens and Spans are only "views" of a Doc;
# they don't have word-level-or-lower data
# of their own.\*
#
# What does that mean? ....
#
# - "Indexing" by Token is really a hard-coded function.
# - Tokens are the most powerful information container in spaCy, in many ways.
# - They are the most manipulable, as you can use them in Python, numpy, or directly in Cython.
# - But don't assume you can access or change information about them easily from the Doc level.
#
# \**(But they do have higher-level,
# syntactic or structural data, of course.)*

# %%
# for ent in doc.ents:
#     print(ent, ent.label_)

ents = {ent: ent.label_ for ent in doc.ents}
ents


from collections import Counter
Counter(ents.values())
# Out:
# Counter({'GPE': 42,
#          'DATE': 44,
#          'PERSON': 122,
#          'ORG': 46,
#          'CARDINAL': 10,
#          'FAC': 1,
#          'NORP': 39,
#          'ORDINAL': 4,
#          'LANGUAGE': 1,
#          'TIME': 2,
#          'LOC': 1,
#          'EVENT': 3})

# %%
doc.__getitem__(3)
doc[3]
# Out:
# a

# %% [markdown]
# Slicing by index only takes a view on doc.text,
# and does not access the metadata.
#
# If you pass a slice, not an int, spaCy
# calls another function and interprets `i[0]`
# as the start index and `i[1]` as the stop.
#
# You can not specify non-contiguous step sizes.
#
# spaCy then returns a Span of token texts.
#
# ```cython
#     start, stop = normalize_slice(len(self), i.start, i.stop, i.step)
#     return Span(self, start, stop, label=0)
# ```

# %%
doc.__getitem__(slice(3,5))
doc[3:5]
# Out:
# a night

# %% [markdown]
# A **Token Span** is different from a character Span. You can see this when slicing into a Doc object. If you exceed the index you specify, the pointer just advances to the next point in the Doc (that's what is meant by "a view").

# %%
#def test_index(doc, slice):
doc[3:5][3] == doc[6]
# Out:
# True

# %%
token_span = doc[3:5]
for token in token_span:
    print(token)

token_span[31]
# Out:
# a
# night
# to

# %% [markdown]
# A Span does not have the same underlying data as its Tokens, but it is a Cython object that can hold its own data, like a label -- e.g., for named entities.
#
# ```cython
# def char_span(self, int start_idx, int end_idx, label=0, kb_id=0, vector=None):
#         """Create a `Span` object from the slice `doc.text[start : end]`.
#         doc (Doc): The parent document.
#         start (int): The index of the first character of the span.
#         end (int): The index of the first character after the span.
#         label (uint64 or string): A label to attach to the Span, e.g. for
#             named entities.
#         kb_id (uint64 or string):  An ID from a KB to capture the meaning of a named entity.
#         vector (ndarray[ndim=1, dtype='float32']): A meaning representation of
#             the span.
#         RETURNS (Span): The newly constructed object.
#         DOCS: https://spacy.io/api/doc#char_span
#         """
#         if not isinstance(label, int):
#             label = self.vocab.strings.add(label)
#         if not isinstance(kb_id, int):
#             kb_id = self.vocab.strings.add(kb_id)
#         cdef int start = token_by_start(self.c, self.length, start_idx)
#         if start == -1:
#             return None
#         cdef int end = token_by_end(self.c, self.length, end_idx)
#         if end == -1:
#             return None
#         # Currently we have the token index, we want the range-end index
#         end += 1
#         cdef Span span = Span(self, start, end, label=label, kb_id=kb_id, vector=vector)
#         return span
# ```

# %% [markdown]
# Doc objects have [several useful attributes](https://spacy.io/api/doc):

# %%
# List sentences

list(doc.sents)
# Out:
# [WASHINGTON —,
#  During a night of heavy drinking at an upscale London bar in May 2016, George Papadopoulos, a young foreign policy adviser to the Trump campaign, made a startling revelation to Australia’s top diplomat in Britain: Russia had political dirt on Hillary Clinton.,
#  About three weeks earlier, Mr. Papadopoulos had been told that Moscow had thousands of emails that would embarrass Mrs. Clinton, apparently stolen in an effort to try to damage her campaign.,
#  Exactly how much Mr. Papadopoulos said that night at the Kensington Wine Rooms with the Australian, Alexander Downer, is unclear.,
#  He was hardly central to the daily running of the Trump campaign, yet Mr. Papadopoulos continuously found ways to make himself useful to senior Trump advisers.,
#  In September 2016, with the United Nations General Assembly approaching and stories circulating that Mrs. Clinton was going to meet with Mr. Sisi, the Egyptian president, Mr. Papadopoulos sent a message to Stephen K. Bannon, the campaign’s chief executive, offering to broker a similar meeting for Mr. Trump.,
#  After days of scheduling discussions, the meeting was set and Mr. Papadopoulos sent a list of talking points to Mr. Bannon, according to people familiar with those interactions.,
#  Asked about his contacts with Mr. Papadopoulos, Mr. Bannon declined to comment.,
#  Mr. Trump’s improbable victory raised Mr. Papadopoulos’s hopes that he might ascend to a top White House job.,
#  The election win also prompted a business proposal from Sergei Millian, a naturalized American citizen born in Belarus.,
#  After he had contacted Mr. Papadopoulos out of the blue over LinkedIn during the summer of 2016, the two met repeatedly in Manhattan.,
#  Mr. Millian has bragged of his ties to Mr. Trump — boasts that the president’s advisers have said are overstated.,
#  He headed an obscure organization called the Russian-American Chamber of Commerce, some of whose board members and clients are difficult to confirm.,
#  Congress is investigating where he fits into the swirl of contacts with the Trump campaign, although he has said he is unfairly being scrutinized only because of his support for Mr. Trump.,
#  Mr. Millian proposed that he and Mr. Papadopoulos form an energy-related business that would be financed by Russian billionaires “who are not under sanctions” and would “open all doors for us” at “,
#  any level all the way to the top.,
#  ”,
#  One billionaire, he said, wanted to explore the idea of opening a Trump-branded hotel in Moscow.,
#  “,
#  I know the president will distance himself from business, but his children might be interested,” he wrote.,
#  Nothing came of his proposals, partly because Mr. Papadopoulos was hoping that Michael T. Flynn, then Mr. Trump’s pick to be national security adviser, might give him the energy portfolio at the National Security Council.,
#  The pair exchanged New Year’s greetings in the final hours of 2016.,
#  “,
#  Happy New Year, sir,” Mr. Papadopoulos wrote.,
#  “,
#  Thank you and same to you, George.,
#  Happy New Year!,
#  ” Mr. Flynn responded, ahead of a year that seemed to hold great promise.,
#  But 2017 did not unfold that way.,
#  Within months, Mr. Flynn was fired, and both men were charged with lying to the F.B.I.,
#  And both became important witnesses in the investigation Mr. Papadopoulos had played a critical role in starting.]

# %%
# "noun chunks", based on dependency relationships

list(doc.noun_chunks)
# Out:
# [a night,
#  heavy drinking,
#  an upscale London bar,
#  May,
#  George Papadopoulos,
#  a young foreign policy adviser,
#  the Trump campaign,
#  a startling revelation,
#  Australia’s top diplomat,
#  Britain,
#  Russia,
#  political dirt,
#  Hillary Clinton,
#  Mr. Papadopoulos,
#  Moscow,
#  thousands,
#  emails,
#  Mrs. Clinton,
#  an effort,
#  her campaign,
#  Mr. Papadopoulos,
#  the Kensington Wine Rooms,
#  the Australian,
#  Alexander Downer,
#  leaked Democratic emails,
#  Australian officials,
#  the information,
#  Mr. Papadopoulos,
#  their American counterparts,
#  four current and former American and foreign officials,
#  direct knowledge,
#  the Australians’ role,
#  The hacking,
#  the revelation,
#  a member,
#  the Trump campaign,
#  inside information,
#  it,
#  factors,
#  the F.B.I.,
#  an investigation,
#  July,
#  Russia,
#  ’s,
#  the election,
#  President Trump’s associates,
#  Mr. Papadopoulos,
#  who,
#  the F.B.I.,
#  a cooperating witness,
#  the improbable match,
#  a blaze,
#  the first year,
#  the Trump administration,
#  his saga,
#  a tale,
#  the Trump campaign,
#  miniature,
#  He,
#  he,
#  expectations,
#  the campaign,
#  itself,
#  he,
#  a tantalizing target,
#  a Russian influence operation,
#  Mr. Trump’s advisers,
#  him,
#  an insignificant campaign volunteer,
#  a “coffee boy,
#  interviews,
#  new documents,
#  he,
#  the campaign,
#  the election,
#  instance,
#  he,
#  a New York meeting,
#  Mr. Trump,
#  President Abdel Fattah el-Sisi,
#  Egypt,
#  The information,
#  Mr. Papadopoulos,
#  the Australians,
#  the lingering mysteries,
#  the past year,
#  What,
#  so alarmed American officials,
#  the F.B.I.,
#  a counterintelligence investigation,
#  the Trump campaign months,
#  the presidential election,
#  It,
#  Mr. Trump,
#  other politicians,
#  a dossier,
#  a former British spy,
#  a rival campaign,
#  it,
#  firsthand information,
#  America’s,
#  closest intelligence allies,
#  Interviews,
#  documents,
#  Mr. Papadopoulos,
#  a critical role,
#  this drama,
#  a Russian operation,
#  They,
#  an emerging portrait,
#  the past year,
#  revelations,
#  federal investigators,
#  journalists,
#  lawmakers,
#  Russians,
#  government contacts,
#  secret channels,
#  various levels,
#  the Trump campaign,
#  The F.B.I. investigation,
#  the special counsel,
#  Robert S. Mueller III,
#  a shadow,
#  Mr. Trump’s,
#  office,
#  he,
#  his aides,
#  the Russian efforts,
#  campaign contacts,
#  Russians,
#  They,
#  Mr. Papadopoulos,
#  a low-level figure,
#  spies,
#  peripheral players,
#  a way,
#  insight,
#  leverage,
#  F.B.I. officials,
#  the Russia inquiry,
#  the election,
#  little debate,
#  what,
#  John O. Brennan,
#  who,
#  four years,
#  C.I.A. director,
#  Congress,
#  May,
#  he,
#  multiple contacts,
#  Russian officials,
#  Trump advisers,
#  Russia,
#  he,
#  members,
#  the Trump campaign,
#  Mr. Papadopoulos,
#  Chicago,
#  an energy consultant,
#  London,
#  the Trump campaign,
#  a foreign policy team,
#  him,
#  an adviser,
#  early March,
#  His political experience,
#  two months,
#  Ben Carson,
#  ’s presidential campaign,
#  it,
#  Mr. Papadopoulos,
#  no experience,
#  Russia issues,
#  his job interview,
#  Sam Clovis,
#  a top early campaign aide,
#  he,
#  an opening,
#  He,
#  relations,
#  Russia,
#  Mr. Trump’s top foreign policy goals,
#  court papers,
#  Mr. Clovis,
#  Italy,
#  Mr. Papadopoulos,
#  Joseph Mifsud,
#  a Maltese professor,
#  a now-defunct London academy,
#  who,
#  valuable contacts,
#  the Russian Ministry,
#  Foreign Affairs,
#  Mr. Mifsud,
#  little interest,
#  Mr. Papadopoulos,
#  he,
#  he,
#  a Trump campaign adviser,
#  he,
#  him,
#  court records,
#  emails,
#  The New York Times,
#  Their joint goal,
#  a meeting,
#  Mr. Trump,
#  President Vladimir V. Putin,
#  Russia,
#  Moscow,
#  their respective aides,
#  response,
#  questions,
#  Mr. Papadopoulos’s lawyers,
#  a statement,
#  the end,
#  the month,
#  Mr. Mifsud,
#  a meeting,
#  a London cafe,
#  Mr. Papadopoulos,
#  Olga Polonskaya,
#  a young woman,
#  St. Petersburg,
#  whom,
#  he,
#  Mr. Putin’s niece,
#  Ms. Polonskaya,
#  The Times,
#  a text message,
#  her English skills,
#  her emails,
#  Mr. Papadopoulos,
#  We,
#  the possibility,
#  a good relationship,
#  Mr. Trump,
#  Ms. Polonskaya,
#  one message,
#  Mr. Mifsud,
#  Mr. Papadopoulos,
#  Ivan Timofeev,
#  a program director,
#  the prestigious Valdai Discussion Club,
#  a gathering,
#  academics,
#  Mr. Putin,
#  The two men,
#  months,
#  the Russian government,
#  the campaign,
#  Records,
#  Mr. Timofeev,
#  who,
#  Mr. Mueller’s team,
#  an intermediary,
#  the Russian Foreign Ministry,
#  the matter,
#  the ministry’s former leader,
#  Igor S. Ivanov,
#  who,
#  the United States,
#  Russia’s elder statesmen,
#  Mr. Trump’s foreign policy team,
#  the first time,
#  the end,
#  March,
#  Washington,
#  Mr. Papadopoulos,
#  he,
#  the contacts,
#  a meeting,
#  Mr. Trump,
#  Mr. Putin,
#  Mr. Trump,
#  Jeff Sessions,
#  then a senator,
#  Alabama,
#  head,
#  the campaign,
#  ’s foreign policy team,
#  participants,
#  the meeting,
#  Mr. Sessions,
#  now the attorney general,
#  that discussion,
#  Congress,
#  he,
#  he,
#  it,
#  he,
#  he,
#  Mr. Papadopoulos’s proposal,
#  he,
#  someone,
#  the campaign,
#  such a sensitive matter,
#  the campaign,
#  Mr. Papadopoulos,
#  , previously undisclosed emails,
#  The Times,
#  he,
#  the message,
#  it,
#  He,
#  months,
#  some kind,
#  meeting,
#  Russian representatives,
#  senior campaign advisers,
#  his efforts,
#  Mr. Clovis,
#  him,
#  another foreign policy adviser,
#  Moscow,
#  the campaign,
#  the cost,
#  Mr. Papadopoulos,
#  the outline,
#  Mr. Trump’s first major foreign policy speech,
#  April,
#  an address,
#  the candidate,
#  it,
#  relations,
#  Russia,
#  Mr. Papadopoulos,
#  the speech,
#  his newfound,
#  Russia,
#  contacts,
#  Mr. Timofeev,
#  it,
#  the signal,
#  “,
#  a statesman speech,
#  Mr. Mifsud,
#  Ms. Polonskaya,
#  she,
#  Mr. Trump,
#  ’s “position,
#  Russia,
#  other candidates,
#  Stephen Miller,
#  a senior policy adviser,
#  the campaign,
#  now a top White House aide,
#  Mr. Papadopoulos,
#  a surrogate,
#  who,
#  Mr. Trump’s foreign policy views,
#  the campaign,
#  But Mr. Papadopoulos’s first public attempt,
#  a disaster,
#  The Times,
#  London,
#  Mr. Papadopoulos,
#  Prime Minister David Cameron,
#  Mr. Trump,
#  his remarks,
#  Muslims,
#  Trump,
#  special relationship,
#  Cameron,
#  the headline,
#  Mr. Clovis,
#  the national campaign co-chairman,
#  Mr. Papadopoulos,
#  his explosive comments,
#  the campaign,
#  advance,
#  Mr. Papadopoulos,
#  he,
#  the full trust,
#  Mr. Clovis,
#  several other campaign officials,
#  Mr. Mifsud,
#  Mr. Papadopoulos,
#  he,
#  a campaign surrogate,
#  He,
#  op-eds,
#  the guise,
#  a “neutral” observer,
#  he,
#  a previously undisclosed email,
#  Mr. Trump,
#  his rallies,
#  an accredited journalist,
#  briefings,
#  the campaign,
#  late April,
#  a London hotel,
#  Mr. Mifsud,
#  Mr. Papadopoulos,
#  he,
#  high-level Russian officials,
#  Moscow,
#  the Russians,
#  “dirt,
#  Mrs. Clinton,
#  the form,
#  “thousands,
#  emails,
#  court documents,
#  Russian hackers,
#  mining data,
#  the Democratic National Committee’s computers,
#  months,
#  information,
#  Even the committee,
#  itself,
#  Mr. Papadopoulos,
#  information,
#  anyone,
#  the campaign,
#  many unanswered questions,
#  He,
#  contact,
#  the campaign,
#  emails,
#  Mr. Mifsud,
#  ’s,
#  the hacked emails,
#  he,
#  Mr. Miller,
#  an email,
#  he,
#  “interesting messages,
#  Moscow,
#  a possible trip,
#  The emails,
#  The Times,
#  no evidence,
#  Mr. Papadopoulos,
#  the stolen messages,
#  the campaign,
#  he,
#  Mr. Downer,
#  the Australian diplomat,
#  his contacts,
#  the Russians,
#  It,
#  Mr. Downer,
#  that information,
#  May,
#  The meeting,
#  the bar,
#  a series,
#  connections,
#  an Israeli Embassy official,
#  who,
#  Mr. Papadopoulos,
#  another Australian diplomat,
#  London,
#  It,
#  the information,
#  May,
#  the Australian government,
#  two months,
#  it,
#  the F.B.I.,
#  a statement,
#  the Australian Embassy,
#  Washington,
#  details,
#  the meeting,
#  it,
#  a matter,
#  principle,
#  practice,
#  the Australian government,
#  matters,
#  active investigations,
#  the statement,
#  The F.B.I.,
#  the information,
#  Mr. Papadopoulos,
#  the Australian diplomat,
#  the F.B.I.,
#  the bureau,
#  an investigation,
#  its most closely guarded secrets,
#  Senior agents,
#  it,
#  the daily morning briefing,
#  a classified setting,
#  officials,
#  highly sensitive operations,
#  the information,
#  the Australians,
#  the investigation,
#  intelligence,
#  other friendly governments,
#  A trip,
#  Moscow,
#  another adviser,
#  Carter Page,
#  concerns,
#  the F.B.I.,
#  so many strands,
#  —,
#  Mr. Papadopoulos,
#  Mr. Page,
#  the hackers,
#  more — F.B.I. agents,
#  the campaign’s,
#  Russia ties,
#  current and former officials,
#  the debate,
#  subpoenas,
#  people,
#  example,
#  the investigation,
#  public view,
#  the final months,
#  a presidential campaign,
#  It,
#  the Russian government,
#  its tracks,
#  Some officials,
#  such disruptive steps,
#  the F.B.I.,
#  the case,
#  the election,
#  Others,
#  the possibility,
#  a compromised presidential campaign,
#  it,
#  the most thorough, aggressive tactics,
#  the odds,
#  a Trump presidency,
#  these agents,
#  it,
#  every precaution,
#  Christopher Steele,
#  the former British spy,
#  who,
#  the dossier,
#  a far-ranging Russian conspiracy,
#  Mr. Trump,
#  A team,
#  F.B.I. agents,
#  Europe,
#  Mr. Steele,
#  early October,
#  Mr. Steele,
#  his findings,
#  an F.B.I. agent,
#  Rome,
#  information,
#  part,
#  the justification,
#  an counterintelligence inquiry,
#  American officials,
#  the F.B.I. and Justice Department,
#  the investigation,
#  a decision,
#  Democrats,
#  agents,
#  Mr. Papadopoulos,
#  late January,
#  He,
#  the daily running,
#  the Trump campaign,
#  Mr. Papadopoulos,
#  ways,
#  himself,
#  senior Trump advisers,
#  September,
#  the United Nations General Assembly,
#  stories,
#  Mrs. Clinton,
#  Mr. Sisi,
#  the Egyptian president,
#  Mr. Papadopoulos,
#  a message,
#  Stephen K. Bannon,
#  the campaign’s chief executive,
#  a similar meeting,
#  Mr. Trump,
#  days,
#  scheduling discussions,
#  the meeting,
#  Mr. Papadopoulos,
#  a list,
#  talking points,
#  Mr. Bannon,
#  people,
#  those interactions,
#  his contacts,
#  Mr. Papadopoulos,
#  Mr. Bannon,
#  Mr. Trump’s,
#  improbable victory,
#  Mr. Papadopoulos’s,
#  he,
#  a top White House job,
#  The election win,
#  a business proposal,
#  Sergei Millian,
#  a naturalized American citizen,
#  Belarus,
#  he,
#  Mr. Papadopoulos,
#  the blue,
#  LinkedIn,
#  the summer,
#  Manhattan,
#  Mr. Millian,
#  his ties,
#  Mr. Trump —,
#  the president,
#  advisers,
#  He,
#  an obscure organization,
#  Commerce,
#  whose board members,
#  clients,
#  Congress,
#  he,
#  the swirl,
#  contacts,
#  the Trump campaign,
#  he,
#  he,
#  his support,
#  Mr. Trump,
#  Mr. Millian,
#  he,
#  Mr. Papadopoulos,
#  an energy-related business,
#  Russian billionaires,
#  who,
#  sanctions,
#  all doors,
#  us,
#  any level,
#  the top,
#  One billionaire,
#  he,
#  the idea,
#  a Trump-branded hotel,
#  Moscow,
#  “,
#  I,
#  the president,
#  himself,
#  business,
#  his children,
#  he,
#  Nothing,
#  his proposals,
#  Mr. Papadopoulos,
#  Michael T. Flynn,
#  national security adviser,
#  him,
#  the energy portfolio,
#  the National Security Council,
#  The pair,
#  New Year’s greetings,
#  the final hours,
#  “,
#  sir,
#  Mr. Papadopoulos,
#  you,
#  you,
#  Happy New Year,
#  Mr. Flynn,
#  a year,
#  great promise,
#  months,
#  Mr. Flynn,
#  both men,
#  the F.B.I.,
#  important witnesses,
#  the investigation,
#  Mr. Papadopoulos,
#  a critical role]

# %%
# entities

doc.ents
# Out:
# (WASHINGTON,
#  London,
#  May 2016,
#  George Papadopoulos,
#  Trump,
#  Australia,
#  Britain,
#  Russia,
#  Hillary Clinton,
#  About three weeks earlier,
#  Papadopoulos,
#  Moscow,
#  thousands,
#  Clinton,
#  Papadopoulos,
#  the Kensington Wine Rooms,
#  Australian,
#  Alexander Downer,
#  two months later,
#  Democratic,
#  Australian,
#  Papadopoulos,
#  American,
#  four,
#  American,
#  Australians,
#  Trump,
#  July 2016,
#  Russia,
#  Trump’s,
#  Papadopoulos,
#  F.B.I.,
#  the first year,
#  Trump,
#  Trump,
#  Russian,
#  Trump’s,
#  Two months,
#  New York,
#  Trump,
#  Abdel Fattah,
#  Egypt,
#  Papadopoulos,
#  Australians,
#  one,
#  the past year,
#  American,
#  Trump,
#  months,
#  Trump,
#  British,
#  America,
#  Interviews,
#  Papadopoulos,
#  Russian,
#  the past year,
#  Russians,
#  Trump,
#  seven months ago,
#  Robert S. Mueller III,
#  Trump’s,
#  first year,
#  Russian,
#  Russians,
#  Papadopoulos,
#  2016,
#  Russia,
#  John O. Brennan,
#  this year,
#  four years,
#  C.I.A.,
#  Congress,
#  May,
#  Russian,
#  Trump,
#  Russia,
#  Trump,
#  Papadopoulos,
#  Chicago,
#  London,
#  Trump,
#  early March 2016,
#  two months,
#  Ben Carson,
#  Papadopoulos,
#  Russia,
#  Sam Clovis,
#  Russia,
#  one,
#  Trump,
#  Clovis,
#  Italy,
#  March,
#  Papadopoulos,
#  Joseph Mifsud,
#  Maltese,
#  London,
#  the Russian Ministry of Foreign Affairs,
#  Mifsud,
#  Papadopoulos,
#  first,
#  Trump,
#  The New York Times,
#  Trump,
#  Vladimir V. Putin,
#  Russia,
#  Moscow,
#  Papadopoulos,
#  the end of the month,
#  Mifsud,
#  London,
#  Papadopoulos,
#  Olga Polonskaya,
#  St. Petersburg,
#  Putin,
#  Polonskaya,
#  Times,
#  English,
#  Papadopoulos,
#  Trump,
#  Polonskaya,
#  one,
#  Mifsud,
#  Papadopoulos,
#  Ivan Timofeev,
#  Valdai Discussion Club,
#  annually,
#  Putin,
#  two,
#  months,
#  Russian,
#  Timofeev,
#  Mueller,
#  the Russian Foreign Ministry,
#  Igor S. Ivanov,
#  the United States,
#  Russia,
#  Trump’s,
#  first,
#  the end of March,
#  Washington,
#  Papadopoulos,
#  Trump,
#  Putin,
#  Trump,
#  Jeff Sessions,
#  Alabama,
#  ’s,
#  Sessions,
#  Congress,
#  Papadopoulos,
#  Papadopoulos,
#  Times,
#  months,
#  Russian,
#  Clovis,
#  Moscow,
#  Papadopoulos,
#  Trump’s,
#  first,
#  April 27,
#  Russia,
#  Papadopoulos,
#  Russia,
#  Timofeev,
#  Mifsud,
#  Polonskaya,
#  Trump,
#  Russia,
#  Stephen Miller,
#  White House,
#  Papadopoulos,
#  Trump’s,
#  Papadopoulos,
#  first,
#  a May 4, 2016,
#  The Times of London,
#  Papadopoulos,
#  David Cameron,
#  Trump,
#  Muslims,
#  Trump,
#  Cameron,
#  Clovis,
#  Papadopoulos,
#  Papadopoulos,
#  Clovis,
#  Mifsud,
#  Papadopoulos,
#  Trump,
#  late April,
#  London,
#  Mifsud,
#  Papadopoulos,
#  Russian,
#  Moscow,
#  Russians,
#  Clinton,
#  thousands,
#  Russian,
#  the Democratic National Committee’s,
#  months,
#  Papadopoulos,
#  The day,
#  Mifsud,
#  Miller,
#  Moscow,
#  Times,
#  Papadopoulos,
#  Downer,
#  Australian,
#  Russians,
#  Downer,
#  May 2016,
#  Israeli Embassy,
#  Papadopoulos,
#  Australian,
#  London,
#  May,
#  Australian,
#  two months,
#  the Australian Embassy,
#  Washington,
#  Australian,
#  F.B.I.,
#  Papadopoulos,
#  Australian,
#  F.B.I.,
#  one,
#  daily,
#  morning,
#  Australians,
#  British,
#  Dutch,
#  Moscow,
#  Carter Page,
#  Papadopoulos,
#  Page,
#  Russia,
#  the final months,
#  Russian,
#  F.B.I.,
#  Trump,
#  Christopher Steele,
#  British,
#  Russian,
#  Trump,
#  Europe,
#  Steele,
#  early October 2016,
#  Steele,
#  Rome,
#  three months earlier,
#  American,
#  F.B.I. and Justice Department,
#  Democrats,
#  Papadopoulos,
#  late January,
#  daily,
#  Trump,
#  Papadopoulos,
#  Trump,
#  September 2016,
#  the United Nations General Assembly,
#  Clinton,
#  Sisi,
#  Egyptian,
#  Papadopoulos,
#  Stephen K. Bannon,
#  Trump,
#  days,
#  Papadopoulos,
#  Bannon,
#  Papadopoulos,
#  Bannon,
#  Trump’s,
#  Papadopoulos’s,
#  White House,
#  Sergei Millian,
#  American,
#  Belarus,
#  Papadopoulos,
#  LinkedIn,
#  the summer of 2016,
#  two,
#  Manhattan,
#  Millian,
#  Trump,
#  the Russian-American Chamber of Commerce,
#  Congress,
#  Trump,
#  Trump,
#  Millian,
#  Papadopoulos,
#  Russian,
#  One,
#  Trump,
#  Moscow,
#  Papadopoulos,
#  Michael T. Flynn,
#  Trump,
#  the National Security Council,
#  New Year’s,
#  the final hours,
#  2016,
#  New Year,
#  Papadopoulos,
#  George,
#  New Year,
#  Flynn,
#  a year,
#  2017,
#  months,
#  Flynn,
#  Papadopoulos)

# %%
sent = list(doc.sents)[2]

# %%
displacy.render(sent, style="dep") # If *not* in a notebook, use .serve() instead
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="09fef137397b4d3897d9fc32effad1db-0" class="displacy" width="5475" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">About</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">earlier,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Papadopoulos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">told</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Moscow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">thousands</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">emails</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">embarrass</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Clinton,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">apparently</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">stolen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">effort</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">try</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">damage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">campaign.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">NOUN

# %% [markdown]
# [Token attributes](https://spacy.io/api/token#attributes)

# %%
token = doc[10]
[token.text, token.lemma_, 
 token.pos_, token.tag_, token.dep_, 
 token.shape_, token.is_alpha, 
 token.is_stop, token.ent_type_, token.ent_id_,
 norm_]
# Out:
# ['Dana', 'Dana', 'PROPN', 'NNP', 'appos', 'Xxxx', True, False, 'PERSON']

# %%
for i, token in enumerate(doc):
    if token.pos_ == "PROPN":
        if "|" in token.text:
            print(doc[i-1], token)
# Out:
# Walter Skinner|Skinner
# Dana Scully|Scully

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
nltk_stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stops = nlp(" ".join([w for w in nltk_stopwords]))

# %%
stop_counts = Counter([token.pos_ for token in stops])

# %%
stop_counts
# Out:
# Counter({'VERB': 41,
#          'PRON': 31,
#          'ADV': 38,
#          'NOUN': 17,
#          'AUX': 11,
#          'ADP': 27,
#          'INTJ': 3,
#          'CCONJ': 4,
#          'DET': 20,
#          'PART': 3,
#          'ADJ': 10})
